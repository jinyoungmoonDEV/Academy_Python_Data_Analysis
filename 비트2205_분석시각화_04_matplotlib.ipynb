# %% [markdown]
# <a href="https://colab.research.google.com/github/jinyoungmoonDEV/Academy_Python_Data_Analysis/blob/main/%EB%B9%84%ED%8A%B82205_%EB%B6%84%EC%84%9D%EC%8B%9C%EA%B0%81%ED%99%94_04_matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # matplotlib.pyplot
# plot([x], y, [fmt], *, data=None, **kwargs)
#
# plot([x], y, [fmt], [x2], y2, [fmt2], ..., **kwargs)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(4,3))
plt.plot([4,2,3,6])
plt.title("only y values")
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(4,3))
plt.plot([1,2,9,10],[4,2,3,6])
plt.title("x and y values")
plt.show()

# %% [markdown]
# fmt = '[marker][line][color]'
#
# maker 점의 위치에 표시할 도형
#
# line 점과 점 사이의 연결선 형태
#
# color색상

# %%
plt.figure(figsize=(4,3))
plt.plot([1,2],[1,1],'.',label='1 .')
plt.plot([1,2],[2,2],'o',label='2 o')
plt.plot([1,2],[3,3],'*',label='3 *')
plt.title("line type")
plt.legend(loc='upper center')
plt.show()

# %%
plt.figure(figsize=(4,3))
plt.plot([1,2],[1,1],'.-',label='1 .-')
plt.plot([1,2],[2,2],'o--',label='2 o--')
plt.plot([1,2],[3,3],'*-.',label='3 *-.')
plt.title("marker and line type")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(4,3))
plt.plot([1,2],[1,1],'.-r',label='1 .-r')
plt.plot([1,2],[2,2],'o--b',label='2 o--')
plt.plot([1,2],[3,3],'*-.m',label='3 *-.m')
plt.title("marker and line type and color")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(4,3))
plt.plot([1,2],[1,1],'.-',color = 'purple',label='1 ,- ')
plt.plot([1,2],[2,2],'o--b',color = '#7F7F00',label='2 o--')
plt.plot([1,2],[3,3],'*-.',color = 'r',label='3 *-.')
plt.title("use color option")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(3,3))
xs = [x/10 for x in range(-50,50)]#-5~5 step:0.1
ys = [2*x**2+3 for x in xs]#y = 2x^2+3
plt.plot(xs,ys,label='y=2xx+3')
plt.xlim(-25,25)
plt.ylim(0,50)
plt.vlines(0,0,50)
plt.legend(loc='lower left')
plt.show()

# %%
plt.figure(figsize=(3,3))
xs = [x/10 for x in range(-50,50)]#-5~5 step:0.1
ys = [2*x**2+3 for x in xs]#y = 2x^2+3
ys2 = [2*x+1 for x in xs]#y = 2x+1
ys3 = [2*x**2+1 for x in xs]#y = 2x^2+1

plt.plot(xs,ys,'.',label='y=2xx+3')
plt.plot(xs,ys2,'-',label='y=2x+1')
plt.plot(xs,ys3,'--',label='y=2xx+1')
plt.xlim(-50,50)
plt.ylim(0,50)
plt.vlines(0,0,50)
#plt.legend(loc='lower left')
plt.show()

# %%
plt.plot(xs,ys)#default로 firgure (figure(1))에 그려줌
plt.figure(2)#이번에 그림을 그릴 figure를 선택
plt.plot(xs,ys2)
plt.figure(3)
plt.plot(xs,ys3)
plt.show()

# %%
ax = plt.subplot(2,2,1)
ax.set_title("um")
plt.subplot(2,2,1)
plt.plot(xs,ys)
plt.subplot(2,2,2)
plt.plot(xs,ys2)
plt.subplot(2,2,3)
plt.plot(xs,ys3)
plt.subplot(2,2,4)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   This is separate from the ipykernel package so we can avoid doing imports until

# %% [markdown]
# # scatter 점과 크기를 조정해 표현
#
# matplotlib.pyplot.scatter(x, y, s=None, c=None, marker=None, cmap=None, norm=None, vmin=None, vmax=None, alpha=None, linewidths=None, * edgecolors=None, plotnonfinite=False, data=None, **kwargs)

# %%
plt.figure(figsize=(4,3))
plt.scatter([1,2],[1,1],label='first')
plt.scatter([1,2],[1,1],[1,8],label='second')
plt.title("scatter")
plt.legend()
plt.show()

# %%
import pandas as pd
temp = [25.3,35.7,45.2]
sales = [1000,2000,2500]
dict_data = {"temp":temp, "sales":sales}
df = pd.DataFrame(dict_data,columns=["temp","sales"])
df
# Out:
#    temp  sales
# 0  25.3   1000
# 1  35.7   2000
# 2  45.2   2500

# %%
df.plot.scatter(x='temp',y='sales')
plt.show()

# %% [markdown]
# bar
#
# matplotlib.pyplot.bar(x, height, width=0.8, bottom=None, *, align='center', data=None, **kwargs)

# %%
plt.figure(figsize=(2.5,2.5))
plt.bar(['a','b','c'],[80,90,75])
plt.show()

# %%
#!sudo apt-get install -y fonts-nanum
#!sudo fc-cache -fx
#!rm ~/ .cache/matplotlib -rf

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(2.5,2.5))
city =['S','I','DJ','DG','U','B','G']
lat = [37.56, 37.45, 36.35, 35.87, 35.53, 35.18, 35.16]
lon = [126.97, 126.70, 127.38,128.60,129.31,129.07,126.85]
pop_den = [16154,2751,2839,2790,1099,4454,2995]
plt.bar(city,pop_den)
plt.show()

# %%
ids = ['m01','m02','m03','m04']
ex = [27,35,40,33]
plt.bar(ids,ex)
plt.grid(True)
plt.show()

# %%
import numpy as np
ids = ['m01','m02','m03','m04']
ex = [27,35,40,33]
idns = np.array([1,2,3,4])
plt.bar(idns,ex)
plt.grid(True)
plt.show()

# %%
import numpy as np
ids = ['m01','m02','m03','m04']
ex = [27,35,40,33]
idns = np.array([1,2,3,4])
cids = idns.astype(str) #x 항목을 문자열로 캐스팅하여 사용하세요.
plt.bar(cids,ex)
plt.grid(True)
plt.show()

# %%
import numpy as np
ids = ['m01','m02','m03','m04']
ex = [27,35,40,33]
idns = np.array([1,2,3,4])
cids = idns.astype(str) #x 항목을 문자열로 캐스팅하여 사용하세요.
plt.bar(cids,ex,color=['r','g','b','m'])
plt.show()

# %%
import numpy as np
ids = ['m01','m02','m03','m04']
ex = [27,35,40,33]
idns = np.array([1,2,3,4])
cids = idns.astype(str) #x 항목을 문자열로 캐스팅하여 사용하세요.
plt.bar(cids,ex,color=['r','g','b','m'],width=0.6)
plt.show()

# %%
import numpy as np
ids = ['m01','m02','m03','m04']
ex = [27,35,40,33] #운동 전
af = [35,40,45,38] #운동 후
bw=0.4
idns = np.array([1,2,3,4])
cids = idns.astype(str) #x 항목을 문자열로 캐스팅하여 사용하세요.
plt.bar(idns,ex,color='r',width=bw,align='before')
plt.bar(idns+bw,af,color='b',width=0.6,align='after')
plt.xticks(idns+bw,cids)
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-130-ea40caf74a7f> in <module>()
#       6 idns = np.array([1,2,3,4])
#       7 cids = idns.astype(str) #x 항목을 문자열로 캐스팅하여 사용하세요.
# ----> 8 plt.bar(idns,ex,color='r',width=bw,align='before')
#       9 plt.bar(idns+bw,af,color='b',width=0.6,align='after')
#      10 plt.xticks(idns+bw,cids)
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py in bar(x, height, width, bottom, align, data, **kwargs)
#    2407     return gca().bar(
#    2408         x, height, width=width, bottom=bottom, align=align,
# -> 2409         **({"data": data} if data is not None else {}), **kwargs)
#    2410
#    2411
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
#    1567         bound = new_sig.bind(ax, *args, **kwargs)
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/axes/_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2364         # We will now resolve the alignment and really have
#    2365         # left, bottom, width, height vectors
# -> 2366         cbook._check_in_list(['center', 'edge'], align=align)
#    2367         if align == 'center':
#    2368             if orientation == 'vertical':
#
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py in _check_in_list(_values, **kwargs)
#    2143             raise ValueError(
#    2144                 "{!r} is not a valid value for {}; supported values are {}"
# -> 2145                 .format(v, k, ', '.join(map(repr, values))))
#    2146
#    2147
#
# ValueError: 'before' is not a valid value for align; supported values are 'center', 'edge'

# %%
plt.barh([1,2,3],[10,20,25])
plt.show()

# %%
import numpy as np
ids = ['m01','m02','m03','m04']
ex = [27,35,40,33]
idns = np.array([1,2,3,4])
cids = idns.astype(str) #x 항목을 문자열로 캐스팅하여 사용하세요.
plt.bar(cids,ex,color=['r','g','b','m'], edgecolor=['g','b','m','r'])
plt.show()

# %%
import numpy as np
ids = ['m01','m02','m03','m04']
ex = [27,35,40,33]
idns = np.array([1,2,3,4])
cids = idns.astype(str) #x 항목을 문자열로 캐스팅하여 사용하세요.
plt.bar(cids,ex,linewidth=4, edgecolor='r',yerr=[1,2,3,2])
plt.show()

# %%
import numpy as np
ids = ['m01','m02','m03','m04']
ex = [27,35,40,33]
idns = np.array([1,2,3,4])
cids = idns.astype(str) #x 항목을 문자열로 캐스팅하여 사용하세요.
plt.bar(cids,ex,linewidth=4, edgecolor='r',yerr=[1,2,3,2],capsize=3)
plt.show()

# %%
import matplotlib.pyplot as plt

# %%
ex_xs = [[2],[4],[7],[1],[9],[6]]
ex_ys = [8,11,24,5,30,20]
plt.figure(figsize=(4,4))
plt.plot(ex_xs[:],ex_ys, 'o', label='example')
plt.legend()
plt.xlim(0,30)
plt.ylim(0,30)
plt.show()

# %%
ex_xs = [[2],[4],[7],[1],[9],[6]]
ex_ys = [8,11,24,5,30,20]
plt.figure(figsize=(4,4))
plt.plot(ex_xs[:],ex_ys, 'o', label='example')
plt.plot([0,30],[2*0+2,2*30+2],label='y=2x+2')
plt.plot([0,30],[3*0+2,3*30+2],label='y=3x+2')
plt.plot([0,30],[4*0+2,4*30+2],label='y=4x+2')
plt.legend()
plt.xlim(0,30)
plt.ylim(0,30)
plt.show()

# %%
def mse(yp,y):
  return np.mean(sum(yp-y)**2)

# %%
b = 2
mses = [] #mse를 보관할 컬렉션
wpl = np.arange(-10,10,0.5) #조사할 기울기 (-10에서 10까지 step:0.5)
for wp in wpl :#기울기 마다
  yp = wp*np.array(ex_xs)+b
  mses.append(mse(yp,ex_ys)) #해당 기울기에서 mse보관
mses

# %%
mi = np.array(mses).argmin()
plt.plot(wpl,mses,'.')
plt.plot(wpl[mi],mses[mi],'or')
plt.show()

# %% [markdown]
# # PIE
#
# matplotlib.pyplot.pie(x, explode=None, labels=None, colors=None, autopct=None, pctdistance=0.6, shadow=False, labeldistance=1.1, startangle=0, radius=1, counterclock=True, wedgeprops=None, textprops=None, center=(0, 0), frame=False, rotatelabels=False, *, normalize=True, data=None)

# %%
plt.pie([19,20,90,7])
plt.show()

# %%
plt.pie([19,20,90,7],explode=[0,0,0,1])
plt.show()

# %%
plt.pie([19,20,90,7],explode=[0,0,0,0.1],labels=['a','b','c','d'])
plt.show()

# %%
plt.pie([19,20,90,7],labels=['a','b','c','d'],colors=['r','g','k','m'])
plt.show()

# %%
plt.pie([19,20,90,7],labels=['a','b','c','d'],colors=['r','g','y','m'],autopct="%.2f")
plt.show()

# %%
plt.pie([19,20,90,7],colors=['r','g','y','m'],autopct="%.2f",pctdistance=0.8)
plt.show()

# %% [markdown]
# # HIST
#
# matplotlib.pyplot.hist(x, bins=None, range=None, density=False, weights=None, cumulative=False, bottom=None, histtype='bar', align='mid', orientation='vertical', rwidth=None, log=False, color=None, label=None, stacked=False, *, data=None, **kwargs)

# %%
import numpy as np

# %%
xs = [np.random.randint(1,7)  for _ in range(1000)]
plt.hist(xs,bins=[1,2,3,4,5,6,7])
plt.show()

# %%
xs = [np.random.randint(1,7)  for _ in range(1000)]
b = plt.hist(xs,bins=[1,2,3,4,5,6,7])
plt.show()

# %% [markdown]
# # 타이타닉 분석 시각화

# %%
import pandas as pd
path = '/content/train_titanic.csv'
data = pd.read_csv(path)
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %% [markdown]
# 1. 총 인원수, 생존자 수, 사망자수는 몇 명인가?

# %%
s_data = data['Survived']
s_data.value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
vc = s_data.value_counts()
plt.pie(vc.values, labels=[f'dead {vc[0]}',f'alive {vc[1]}'],autopct="%.2f%%")
plt.show()

# %% [markdown]
# 2.결측 데이터가 있는 칼럼들을 조사

# %%
data.info() #non0null count의 카운트된 숫자가 다른 것이 결측 데이터
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# 3.Pclass의 종류에 따른 분포를 나타내기
#
#   Pclass 종류에 따른 생존 유무를 비교

# %%
p_data = data['Pclass']
pvc = p_data.value_counts().sort_index()
plt.pie(pvc.values,labels = pvc.index, autopct="%.2f%%")
plt.title("Pcalss")
plt.show()

# %%
pvc = p_data.value_counts().sort_index()
pc_alive_arr = np.zeros(3) # or len(p_data.unique())
pc_dead_arr = np.zeros(3)
for index in range(len(p_data)):
  pi = p_data[index]-1 #클래스 번호 -1을 배열의 인덱스로 사용
  if s_data[index] == 0:
    pc_dead_arr[pi] += 1
  else:
    pc_alive_arr[pi] += 1
pc_alive_arr, pc_dead_arr
# Out:
# (array([136.,  87., 119.]), array([ 80.,  97., 372.]))

# %%
plt.bar(['1','2','3'],pc_alive_arr)
plt.bar(['1','2','3'],pc_dead_arr,bottom=pc_alive_arr)
for i in range(3):
  plt.annotate(str(pc_alive_arr[i]),(i-0.12,40))
  plt.annotate(str(pc_dead_arr[i]),(i-0.12,pc_alive_arr[i]+40))
plt.show()

# %% [markdown]
# # 4. Name에 부르는 호칭(Mr,Mrs,Miss,Master,Dr,ETC)에 따라 분포와 생존 비율을 분석

# %%
n_data = data['Name']
name_values = ["Mr","Mrs","Miss","Master","Dr","ETC"]
def get_name_index(name):
  _,s = name.split(',')
  sarr = s.split('.')
  lfrag = sarr[0].replace(' ','')
  for index in range(5):
    if lfrag == name_values[index]:
      return index
  return 5
for n in n_data:
  print(get_name_index(n),n)

# %%
pn_alive_arr = np.zeros(6)
pn_dead_arr = np.zeros(6)
cnts=np.zeros(6)
for index in range(len(n_data)):
  ni = get_name_index(n_data[index]) #호칭 인덱스를 구함
  if s_data[index] == 0:
    pn_dead_arr[ni] += 1
  else:
    pn_alive_arr[ni] += 1
  cnts[ni]+=1
pn_alive_arr, pn_dead_arr,cnts
# Out:
# (array([ 81.,  99., 127.,  23.,   3.,   9.]),
#  array([436.,  26.,  55.,  17.,   4.,  11.]),
#  array([517., 125., 182.,  40.,   7.,  20.]))

# %%
plt.pie(cnts, labels=name_values,autopct='%.2f%%')
plt.show()

# %%
plt.bar(name_values,pn_alive_arr)
plt.bar(name_values,pn_dead_arr,bottom=pn_alive_arr)
for i in range(6):
  plt.annotate(str(pn_alive_arr[i]),(i-0.12,40))
  if pn_alive_arr[i]<40:
    plt.annotate(str(pn_dead_arr[i]),(i-0.12,80))
  else:
    plt.annotate(str(pn_dead_arr[i]),(i-0.12,pn_alive_arr[i]+40))
plt.show()
